# %%
import sklearn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("C:\\Users\\preet\\Documents\\RenEnergy\\renewables.csv")

#print (df)

df.head()
# Out:
#    Year  Iceland  Switzerland  United States of America
# 0  1990    54.67        16.80                      4.18
# 1  1991    54.79        17.11                      4.51
# 2  1992    54.63        17.01                      4.76
# 3  1993    54.66        17.99                      4.28
# 4  1994    54.14        18.33                      4.09

# %%
sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
df.plot( x= 'Year' , y=['Iceland','Switzerland','United States of America'], linestyle='dashed'  ) 
plt.ylabel('Share of modern renewables')
# Out:
# Text(0, 0.5, 'Share of modern renewables')

# %%
plt.savefig("seaborn_plot.pdf", format='pdf')
